# %%
#Enter your solution here
import pandas as pd
import pymysql

# %%
db = pymysql.connect(host='localhost', port=3306, user='root', passwd='MyNewPass', db='chicagotaxidb')

# %%
def getRes(query):
    df = pd.read_sql(query, con=db)
    return df

# %%
db.close()

# %%
getRes("select Company,avg(fare/trip_miles) as Fare_Rate, avg((fare/Trip_Seconds)*60) as Fare_Minute,count(1) as No_Of_Trips from taxi_mini group by Company order by Fare_Rate desc;")
# Out:
#                                Company  Fare_Rate  Fare_Minute  count(1)
# 0    Blue Ribbon Taxi Association Inc.  69.724487     1.001845      3819
# 1            Taxi Affiliation Services  22.837999     1.072765     24519
# 2                 3201 - CD Cab Co Inc   8.524662     1.199276        22
# 3               1469 - 64126 Omar Jada   7.351826     0.963714        54
# 4             5006 - 39261 Salifu Bawa   6.928263     0.991097        61
# 5                              Unknown   6.265291     1.199601     83082
# 6      0694 - 59280 Chinesco Trans Inc   6.252364     0.949754        38
# 7            5724 - 75306 KYVI Cab Inc   6.249065     1.032381        30
# 8          1085 - 72312 N and W Cab Co   6.200230     1.061084        72
# 9            6057 - 24657 Richard Addo   6.058884     0.873378        39
# 10         6574 - Babylon Express Inc.   6.043612     0.980317        70
# 11             6743 - 78771 Luhak Corp   6.027147     0.888256        73
# ...

# %%
getRes("select Pickup_Community_Area,avg(fare/trip_miles) as Fare_Rate, avg(fare*60/Trip_Seconds) as Fare_Minute ,count(1) as No_Of_Trips from taxi_mini group by Pickup_Community_Area order by Fare_Rate desc;")
# Out:
#     Pickup_Community_Area  Fare_Rate  Fare_Minute  No_Of_Trips
# 0                      66  63.000000     0.860870            2
# 1                      73  42.931818     1.046569            4
# 2                      18  36.475065     1.037593            3
# 3                      40  34.275432     1.049009           13
# 4                      15  34.075771     2.180764           81
# 5                      42  31.926525     1.132669           26
# 6                      19  30.383892     1.049847           29
# 7                      52  29.479575     1.134788            3
# 8                      63  27.054398     1.008761            3
# 9                      48  26.771132     1.094263            7
# 10                     31  25.957860     1.219250           72
# 11                     27  25.877539     1.219173           15
# 12                     69  25.774990     1.058536           11
# 13                     39  25.520069     1.464024          134
# ...

# %%
getRes("select avg(tips) from taxi_mini where tips < (2*fare);")
# Out:
#    avg(tips)
# 0   1.838265
